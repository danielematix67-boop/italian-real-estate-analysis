# %% [markdown]
# # 01 — OMI Data Exploration

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load data

# %%
# =============================================================================
# CONFIGURATION
# =============================================================================

CWD = Path.cwd()
PROJECT_ROOT = CWD.parent

INPUT_FOLDER = PROJECT_ROOT / "data" / "raw" / "omi"

FILE_PREVIEW = INPUT_FOLDER / "omi_quotations_2018_S1.csv"


# =============================================================================
# LOAD DATA
# =============================================================================

df_omi_example = pd.read_csv(
    FILE_PREVIEW,
    sep=";",
)

df_omi_example.head()
# Out:
#   Area_territoriale   Regione Prov  Comune_ISTAT Comune_cat Sez Comune_amm  \
# 0        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 1        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 2        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 3        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 4        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
#
#   Comune_descrizione Fascia Zona  ...      Descr_Tipologia    Stato  \
# 0        ALESSANDRIA      B   B1  ...    Abitazioni civili  NORMALE
# 1        ALESSANDRIA      B   B1  ...                  Box  NORMALE
# 2        ALESSANDRIA      B   B1  ...   Posti auto coperti  NORMALE
# 3        ALESSANDRIA      B   B1  ...  Posti auto scoperti  NORMALE
# 4        ALESSANDRIA      B   B1  ...            Magazzini  NORMALE
#
#   Stato_prev Compr_min Compr_max  Sup_NL_compr  Loc_min Loc_max Sup_NL_loc  \
# 0          P     720.0     910.0             L        4     5,1          L
# 1          P    1100.0    1600.0             L      4,4     6,2          L
# 2          P     700.0    1000.0             L      2,7     3,8          L
# 3          P     600.0     800.0             L      2,5     3,3          L
# 4          P     900.0    1300.0             L      4,8     5,7          L
#
#   Unnamed: 21
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
file_names = [
    file for file in INPUT_FOLDER.iterdir()
    if file.suffix == ".csv"
]


def extract_data_from_file_name(file_name):
    parts = file_name.stem.split("_")

    year = int(parts[2])
    semester = parts[3]

    if semester == "S1":
        month = 6
    elif semester == "S2":
        month = 12
    else:
        raise ValueError(f"Invalid semester: {semester}")

    return pd.Timestamp(
        year=year,
        month=month,
        day=1,
    ) + pd.offsets.MonthEnd(0)


def import_csv_files_with_reference_data(file_names):
    dataframes = []

    for file_name in file_names:
        df = pd.read_csv(
            file_name,
            sep=";",
        )

        df["reference_date"] = extract_data_from_file_name(file_name)

        dataframes.append(df)

    return pd.concat(
        dataframes,
        ignore_index=True,
    )

df_omi = import_csv_files_with_reference_data(file_names)

df_omi.head()
# Out:
#   Area_territoriale   Regione Prov  Comune_ISTAT Comune_cat Sez Comune_amm  \
# 0        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 1        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 2        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 3        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
# 4        NORD-OVEST  PIEMONTE   AL     1006003.0       A2AA           A182
#
#   Comune_descrizione Fascia Zona  ...    Stato  Stato_prev Compr_min  \
# 0        ALESSANDRIA      B   B1  ...  NORMALE           P     720.0
# 1        ALESSANDRIA      B   B1  ...  NORMALE           P    1100.0
# 2        ALESSANDRIA      B   B1  ...  NORMALE           P     700.0
# 3        ALESSANDRIA      B   B1  ...  NORMALE           P     600.0
# 4        ALESSANDRIA      B   B1  ...  NORMALE           P     900.0
#
#   Compr_max Sup_NL_compr  Loc_min  Loc_max Sup_NL_loc Unnamed: 21  \
# 0     910.0            L        4      5,1          L         NaN
# 1    1600.0            L      4,4      6,2          L         NaN
# 2    1000.0            L      2,7      3,8          L         NaN
# 3     800.0            L      2,5      3,3          L         NaN
# 4    1300.0            L      4,8      5,7          L         NaN
#
#   reference_date
# 0     2018-06-30
# 1     2018-06-30
# 2     2018-06-30
# 3     2018-06-30
# 4     2018-06-30
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 3. Dataset overview

# %% [markdown]
# ## 4. Temporal coverage

# %% [markdown]
# ## 5. Geographic coverage

# %% [markdown]
# ## 6. Property categories

# %% [markdown]
# ## 7. OMI quotations

# %% [markdown]
# ## 8. Transaction volumes

# %% [markdown]
# ## 9. Missing values

# %% [markdown]
# ## 10. Duplicates

# %% [markdown]
# ## 11. Data consistency

# %% [markdown]
# ## 12. Initial descriptive statistics

# %% [markdown]
# ## 13. First visualizations

# %% [markdown]
# ## 14. Conclusions
